# 212  -1.112053   6.441450  0.049809 -2.050463  0.021670 -2.021307 -0.007493
# ...        ...        ...       ...       ...       ...       ...       ...
# 4363 -0.937888  12.864375 -0.114359 -2.040542 -0.090848 -1.964862 -0.070132
# 4367 -0.925750   9.906454  0.057757 -2.200202  0.104522 -1.973843  0.107101
# 4371 -0.925410  12.690378 -0.062727 -2.749317 -0.036357 -2.387249 -0.031160
# 4375 -0.749498  13.765900 -0.907510 -1.819428 -0.700910 -1.643393 -0.509169
# 4379 -0.775991  12.714905 -0.662472 -1.920445 -0.503616 -1.723199 -0.361787
#
#             Y7        X8        Y8
# 199  -1.744075 -0.038436 -0.931484
# 203  -1.923888 -0.080444 -1.001955
# 207  -2.199436  0.013333 -1.223844
# 210  -2.052571  0.070028 -1.224312
# 212  -1.950322 -0.060942 -1.198235
# ...        ...       ...       ...
# 4363 -1.774386 -0.075756 -1.011233
# 4367 -1.630030  0.024884 -0.878879
# 4371 -1.891681 -0.063056 -0.973566
# 4375 -1.390107 -0.281888 -0.791154
# 4379 -1.437736 -0.204369 -0.784314
#
# [565 rows x 17 columns]

# %%
# import seaborn as sns
# sns.pairplot(DataA2_prepared)

# %%
# split the data 
from sklearn.model_selection import train_test_split

train_set, test_set = train_test_split(DataA2_prepared, test_size=0.2, random_state=42)

# %%
test_set.head()
# Out:
#             X1        Y1        X2        Y2        X3        Y3        X4  \
# 4130 -1.613095 -1.672301 -1.388763 -1.504112 -1.136296 -1.270005 -0.844277
# 4055 -1.450902 -2.543106 -1.246613 -2.131712 -1.016419 -1.629001 -0.677649
# 1649 -1.298824 -2.731902 -1.130163 -2.253866 -0.947102 -1.724925 -0.686674
# 4059 -1.985237 -2.801260 -1.676860 -2.261217 -1.345593 -1.698950 -0.941107
# 3807 -0.755273 -1.695087 -0.702325 -1.660150 -0.627282 -1.453209 -0.541889
#
#             Y4      Angle        X5        Y5        X6        Y6        X7  \
# 4130 -0.750755  20.732827 -0.825157 -2.066704 -0.631005 -1.775144 -0.465377
# 4055 -0.861217  14.114061 -0.566058 -3.001180 -0.456821 -2.536028 -0.357403
# 1649 -0.901597  15.367216 -0.491003 -3.258789 -0.396251 -2.704169 -0.314501
# 4059 -0.912319  18.628301 -1.168936 -3.374410 -0.910250 -2.704937 -0.677405
# 3807 -0.900773   6.654806 -0.153227 -1.570173 -0.124595 -1.645819 -0.074854
#
#             Y7        X8        Y8
# 4130 -1.488661 -0.286156 -0.815635
# 4055 -1.935943 -0.202497 -0.977525
# 1649 -2.042154 -0.196149 -1.034107
# 4059 -2.031934 -0.408671 -1.099780
# 3807 -1.583570 -0.068648 -0.955907

# %%
DataA2_prepared = train_set.copy()

# %%
corr_matrix = DataA2_prepared.corr()
corr_matrix["Angle"].sort_values(ascending=False)
# Out:
# Angle    1.000000
# Y8       0.024085
# Y4       0.009592
# Y7      -0.014431
# X8      -0.017906
# X5      -0.022485
# X6      -0.024434
# X7      -0.031372
# Y3      -0.045266
# Y6      -0.062447
# Y2      -0.077907
# Y1      -0.095972
# X4      -0.097761
# Y5      -0.108681
# X3      -0.123573
# X2      -0.131576
# X1      -0.134868
# Name: Angle, dtype: float64

# %%
# Prepare the data for Machine Learning algorithms

DataA2_prepared = train_set.drop("Angle", axis=1) # drop labels for training set
DataA2_prepared_label = train_set["Angle"].copy()

# %%
# Select and train a model 

from sklearn.ensemble import RandomForestRegressor
dc_tr=RandomForestRegressor(n_estimators=100,random_state=42)
dc_tr.fit(DataA2_prepared, DataA2_prepared_label)
# Out:
# RandomForestRegressor(random_state=42)

# %%
some_data = DataA2_prepared.iloc[:5]
some_labels = DataA2_prepared_label.iloc[:5]
print("Predictions:", dc_tr.predict(some_data))
# Out:
# Predictions: [14.55148625 15.9990795  15.02941676 16.10138092 11.61304229]

# %%
# Compare against the actual values:

print("Labels:", list(some_labels))
# Out:
# Labels: [15.88187723, 16.7685907, 15.73902838, 16.10828101, 11.24659127]

# %%
from sklearn.metrics import mean_squared_error

Data_predictions = dc_tr.predict(DataA2_prepared)
lin_mse = mean_squared_error(DataA2_prepared_label, Data_predictions)
lin_rmse = np.sqrt(lin_mse)
lin_rmse
# Out:
# 1.6480953489593004

# %%
# Cross Validation

from sklearn.model_selection import cross_val_score

lin_scores = cross_val_score(dc_tr, DataA2_prepared, DataA2_prepared_label,
                         scoring="neg_mean_squared_error", cv=10)
lin_rmse_scores = np.sqrt(-lin_scores)

# %%
def display_scores(scores):
    print("Scores:", scores)
    print("Mean:", scores.mean())
    print("Standard deviation:", scores.std())

display_scores(lin_rmse_scores)
# Out:
# Scores: [4.95701725 3.61486509 3.90623397 3.92206976 4.43994359 5.07572158
#  4.27704792 4.32507639 4.27420079 4.91066923]
# Mean: 4.370284555874072
# Standard deviation: 0.4632096275214885

# %%
X_test = test_set.drop("Angle", axis=1)
y_test = test_set["Angle"].copy()

final_predictions = dc_tr.predict(X_test)

final_mse = mean_squared_error(y_test, final_predictions)
final_rmse = np.sqrt(final_mse)

# %%
plt.scatter(y_test, final_predictions)

# %%
plt.hist(y_test - final_predictions)
# Out:
# (array([ 8., 11., 10., 20., 24., 15., 11.,  6.,  6.,  2.]),
#  array([-7.865633  , -5.985759  , -4.105885  , -2.226011  , -0.346137  ,
#          1.533737  ,  3.413611  ,  5.29348499,  7.17335899,  9.05323299,
#         10.93310699]),
#  <BarContainer object of 10 artists>)

# %%
final_rmse
# Out:
# 4.146845650829588

# %%
from scipy import stats

confidence = 0.95
squared_errors = (final_predictions - y_test) ** 2
np.sqrt(stats.t.interval(confidence, len(squared_errors) - 1,
                         loc=squared_errors.mean(),
                         scale=stats.sem(squared_errors)))
# Out:
# array([3.61433097, 4.61836219])

# %%
import sklearn.metrics as sm

print("Regressor model performance:")
print("Mean absolute error(MAE) =", round(sm.mean_absolute_error(y_test, final_predictions), 2))
print("Mean squared error(MSE) =", round(sm.mean_squared_error(y_test, final_predictions), 2))
print("Median absolute error =", round(sm.median_absolute_error(y_test, final_predictions), 2))
print("Explain variance score =", round(sm.explained_variance_score(y_test, final_predictions), 2))
print("R2 score =", round(sm.r2_score(y_test, final_predictions), 2))
# Out:
# Regressor model performance:
# Mean absolute error(MAE) = 3.34
# Mean squared error(MSE) = 17.2
# Median absolute error = 2.56
# Explain variance score = 0.26
# R2 score = 0.25

# %%
def mean_absolute_percentage_error(y_test, final_predictions): 
    y_test, final_predictions = np.array(y_test), np.array(final_predictions)
    return np.mean(np.abs((y_test - final_predictions) / final_predictions)) * 100

# %%
print(mean_absolute_percentage_error(y_test, final_predictions))
# Out:
# 27.01641174956612
