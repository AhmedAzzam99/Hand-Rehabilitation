# 211   0.574979  16.439768 -0.531509 -2.420218 -0.567882 -2.248802 -0.601912
# ...        ...        ...       ...       ...       ...       ...       ...
# 4362  0.487378  30.575071 -0.770054 -1.893753 -0.727278 -1.838522 -0.666565
# 4366  0.305616  23.213813 -0.703868 -1.983903 -0.615738 -1.846945 -0.526944
# 4370  0.454891  33.790661 -0.794807 -2.496720 -0.714499 -2.147230 -0.636470
# 4374  0.434821  35.377157 -1.610579 -1.427551 -1.396701 -1.383452 -1.132595
# 4378  0.374657  31.241070 -1.440972 -1.620398 -1.243105 -1.525755 -1.004849
#
#             Y7        X8        Y8
# 198  -1.613906 -0.563733 -0.927387
# 202  -1.718436 -0.586272 -0.947346
# 206  -2.120472 -0.573411 -1.183757
# 209  -2.172575 -0.516250 -1.211870
# 211  -1.933344 -0.625079 -1.112053
# ...        ...       ...       ...
# 4362 -1.619898 -0.561699 -0.937888
# 4366 -1.577743 -0.458771 -0.925750
# 4370 -1.694570 -0.544630 -0.925410
# 4374 -1.226493 -0.769300 -0.749498
# 4378 -1.308904 -0.691679 -0.775991
#
# [550 rows x 17 columns]

# %%
# import seaborn as sns
# sns.pairplot(DataA1_prepared)

# %%
# split the data 
from sklearn.model_selection import train_test_split

train_set, test_set = train_test_split(DataA1_prepared, test_size=0.2, random_state=42)

# %%
test_set.head()
# Out:
#             X1        Y1        X2        Y2        X3        Y3        X4  \
# 1405 -2.493009 -0.509432 -1.980968 -0.168027 -1.341341  0.152161 -0.560656
# 481  -1.426740 -1.053591 -1.517450 -0.607311 -1.210207 -0.070835 -0.676489
# 3826 -2.259753 -0.479583 -1.910121 -0.126751 -1.338892  0.151012 -0.639846
# 738  -2.282989 -0.426639 -1.894655 -0.100942 -1.341367  0.197210 -0.622295
# 4129 -2.515569  0.051075 -1.974806  0.256964 -1.384681  0.430380 -0.578739
#
#             Y4      Angle        X5        Y5        X6        Y6        X7  \
# 1405  0.427541  35.539265 -1.393944 -2.034736 -1.186449 -1.759781 -0.967187
# 481   0.397620  24.225420 -0.331185 -2.530120 -0.351517 -2.250228 -0.365188
# 3826  0.379210  28.281757 -0.892097 -1.779430 -0.788002 -1.688927 -0.670323
# 738   0.415472  37.374066 -1.091504 -2.163763 -0.944544 -1.916681 -0.776950
# 4129  0.546922  31.145061 -1.613095 -1.672301 -1.388763 -1.504112 -1.136296
#
#             Y7        X8        Y8
# 1405 -1.442084 -0.721789 -0.862870
# 481  -1.819577 -0.408341 -1.007366
# 3826 -1.454819 -0.537499 -0.885098
# 738  -1.548401 -0.566741 -0.903433
# 4129 -1.270005 -0.844277 -0.750755

# %%
DataA1_prepared = train_set.copy()

# %%
corr_matrix = DataA1_prepared.corr()
corr_matrix["Angle"].sort_values(ascending=False)
# Out:
# Angle    1.000000
# Y2       0.373334
# Y1       0.303164
# Y7       0.274095
# Y8       0.222223
# Y3       0.218522
# Y6       0.150328
# Y5       0.046130
# X8      -0.034133
# X4      -0.066312
# X7      -0.096161
# X6      -0.138009
# X5      -0.180626
# Y4      -0.185230
# X3      -0.462733
# X2      -0.681041
# X1      -0.763683
# Name: Angle, dtype: float64

# %%
# Prepare the data for Machine Learning algorithms

DataA1_prepared = train_set.drop("Angle", axis=1) # drop labels for training set
DataA1_prepared_label = train_set["Angle"].copy()

# %%
# Select and train a model 

from sklearn.ensemble import RandomForestRegressor
dc_tr=RandomForestRegressor(n_estimators=100,random_state=42)
dc_tr.fit(DataA1_prepared, DataA1_prepared_label)
# Out:
# RandomForestRegressor(random_state=42)

# %%
some_data = DataA1_prepared.iloc[:5]
some_labels = DataA1_prepared_label.iloc[:5]
print("Predictions:", dc_tr.predict(some_data))
# Out:
# Predictions: [34.98208946 27.58003365 18.89991035 37.07774055 28.08231253]

# %%
# Compare against the actual values:

print("Labels:", list(some_labels))
# Out:
# Labels: [33.51776307, 26.29113155, 18.95899671, 35.9735304, 29.33379826]

# %%
from sklearn.metrics import mean_squared_error

Data_predictions = dc_tr.predict(DataA1_prepared)
lin_mse = mean_squared_error(DataA1_prepared_label, Data_predictions)
lin_rmse = np.sqrt(lin_mse)
lin_rmse
# Out:
# 1.784075154026798

# %%
# Cross Validation

from sklearn.model_selection import cross_val_score

lin_scores = cross_val_score(dc_tr, DataA1_prepared, DataA1_prepared_label,
                         scoring="neg_mean_squared_error", cv=10)
lin_rmse_scores = np.sqrt(-lin_scores)

# %%
def display_scores(scores):
    print("Scores:", scores)
    print("Mean:", scores.mean())
    print("Standard deviation:", scores.std())

display_scores(lin_rmse_scores)
# Out:
# Scores: [3.81290933 5.72145157 4.69728288 3.30613786 4.477659   5.22141201
#  4.84934982 4.91911991 6.05115804 4.53471608]
# Mean: 4.759119650468072
# Standard deviation: 0.7734838449058282

# %%
X_test = test_set.drop("Angle", axis=1)
y_test = test_set["Angle"].copy()

final_predictions = dc_tr.predict(X_test)

final_mse = mean_squared_error(y_test, final_predictions)
final_rmse = np.sqrt(final_mse)

# %%
plt.scatter(y_test, final_predictions)

# %%
plt.hist(y_test - final_predictions)
# Out:
# (array([ 1.,  0.,  0.,  0.,  1., 20., 48., 31.,  7.,  2.]),
#  array([-28.95810798, -24.61282351, -20.26753905, -15.92225458,
#         -11.57697011,  -7.23168564,  -2.88640117,   1.45888329,
#           5.80416776,  10.14945223,  14.4947367 ]),
#  <BarContainer object of 10 artists>)

# %%
final_rmse
# Out:
# 4.86431448372008

# %%
from scipy import stats

confidence = 0.95
squared_errors = (final_predictions - y_test) ** 2
np.sqrt(stats.t.interval(confidence, len(squared_errors) - 1,
                         loc=squared_errors.mean(),
                         scale=stats.sem(squared_errors)))
# Out:
# array([2.79514118, 6.28572164])

# %%
import sklearn.metrics as sm

print("Regressor model performance:")
print("Mean absolute error(MAE) =", round(sm.mean_absolute_error(y_test, final_predictions), 2))
print("Mean squared error(MSE) =", round(sm.mean_squared_error(y_test, final_predictions), 2))
print("Median absolute error =", round(sm.median_absolute_error(y_test, final_predictions), 2))
print("Explain variance score =", round(sm.explained_variance_score(y_test, final_predictions), 2))
print("R2 score =", round(sm.r2_score(y_test, final_predictions), 2))
# Out:
# Regressor model performance:
# Mean absolute error(MAE) = 3.26
# Mean squared error(MSE) = 23.66
# Median absolute error = 2.62
# Explain variance score = 0.69
# R2 score = 0.69

# %%
def mean_absolute_percentage_error(y_test, final_predictions): 
    y_test, final_predictions = np.array(y_test), np.array(final_predictions)
    return np.mean(np.abs((y_test - final_predictions) / final_predictions)) * 100

# %%
print(mean_absolute_percentage_error(y_test, final_predictions))
# Out:
# 11.48443585325077
